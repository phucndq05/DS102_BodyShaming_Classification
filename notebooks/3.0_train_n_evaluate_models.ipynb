# %%
# 1. Cài đặt thư viện cần thiết
# !pip install transformers scikit-learn pandas matplotlib seaborn vncorenlp

# 2. Mount Google Drive
from google.colab import drive
import os

drive.mount('/content/drive')

# --- CẤU HÌNH ĐƯỜNG DẪN DỰ ÁN ---
PROJECT_PATH = '/content/drive/My Drive/DS102_BodyShaming_Classification'

# Di chuyển thư mục làm việc về root dự án
os.chdir(PROJECT_PATH)
print(f" Current Working Directory: {os.getcwd()}")
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: vncorenlp in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  Current Working Directory: /content/drive/My Drive/DS102_BodyShaming_Classification

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

# Thêm đường dẫn project vào hệ thống để import được 'src'
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)

# Import các class từ file models.py
from src.models import PhoBERTClassifier, BaselineModel

print("Import thành công các module từ src!")
# Out:
# Import thành công các module từ src!

# %%
import pandas as pd
import os

# Cấu hình đường dẫn dữ liệu
DATA_DIR = os.path.join(PROJECT_PATH, 'data', 'processed')

# --- 1. Load dữ liệu cho Deep Learning (PhoBERT) ---
# Dùng file _dl.csv (Text gốc hoặc xử lý nhẹ)
print("--- Loading DL Data (PhoBERT) ---")
df_train_dl = pd.read_csv(os.path.join(DATA_DIR, 'train_dl.csv'))
df_val_dl   = pd.read_csv(os.path.join(DATA_DIR, 'val_dl.csv'))
df_test_dl  = pd.read_csv(os.path.join(DATA_DIR, 'test_dl.csv'))

# Chuyển đổi sang numpy array
X_train_dl = df_train_dl['text'].astype(str).values
y_train_dl = df_train_dl['label'].values

X_val_dl   = df_val_dl['text'].astype(str).values
y_val_dl   = df_val_dl['label'].values

X_test_dl  = df_test_dl['text'].astype(str).values
y_test_dl  = df_test_dl['label'].values

print(f"DL Train shape: {X_train_dl.shape}")
print(f"DL Val shape:   {X_val_dl.shape}")
print(f"DL Test shape:  {X_test_dl.shape}")


# --- 2. Load dữ liệu cho Machine Learning (SVM/NB) ---
print("\n--- Loading Stat Data (ML Models) ---")
df_train_stat = pd.read_csv(os.path.join(DATA_DIR, 'train_stat.csv'))
df_val_stat   = pd.read_csv(os.path.join(DATA_DIR, 'val_stat.csv'))
df_test_stat  = pd.read_csv(os.path.join(DATA_DIR, 'test_stat.csv'))

X_train_stat = df_train_stat['text'].astype(str).values
y_train_stat = df_train_stat['label'].values

X_val_stat   = df_val_stat['text'].astype(str).values
y_val_stat   = df_val_stat['label'].values

X_test_stat  = df_test_stat['text'].astype(str).values
y_test_stat  = df_test_stat['label'].values

print(f"Stat Train shape: {X_train_stat.shape}")
print(f"Stat Val shape:   {X_val_stat.shape}")
print(f"Stat Test shape:  {X_test_stat.shape}")
# Out:
# --- Loading DL Data (PhoBERT) ---
# DL Train shape: (3182,)
# DL Val shape:   (682,)
# DL Test shape:  (682,)
#
# --- Loading Stat Data (ML Models) ---
# Stat Train shape: (3180,)
# Stat Val shape:   (682,)
# Stat Test shape:  (682,)

# %%
# Hàm vẽ confusion matrix
def plot_cm(y_true, y_pred, title="Confusion Matrix"):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['0', '1', '2'],
                yticklabels=['0', '1', '2'])
    plt.title(title)
    plt.ylabel('Thực tế (Actual)')
    plt.xlabel('Dự đoán (Predicted)')
    plt.show()

# %% [markdown]
# # SVM

# %%
print(f"{'='*20} SVM {'='*20}")

# 1. Khoi tao va Train
svm_model = BaselineModel(model_type='svm')
svm_model.train(X_train_stat, y_train_stat)

# 2. Danh gia
print("\nKet qua tren tap Validation (SVM):")
y_pred_svm = svm_model.predict(X_val_stat)
print(classification_report(y_val_stat, y_pred_svm))

# 3. Ve Confusion Matrix
plot_cm(y_val_stat, y_pred_svm, title="Confusion Matrix - SVM")

# 4. Luu model
save_path_svm = os.path.join(PROJECT_PATH, 'demo', 'artifacts', 'svm.pkl')
svm_model.save(save_path_svm)
# Out:
# ==================== SVM ====================
# -> [Baseline] Đang huấn luyện mô hình: svm...
# -> [Baseline] Huấn luyện hoàn tất.
#
# Ket qua tren tap Validation (SVM):
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       534
#            1       0.35      0.48      0.41        82
#            2       0.45      0.42      0.44        66
#
#     accuracy                           0.76       682
#    macro avg       0.56      0.58      0.57       682
# weighted avg       0.78      0.76      0.77       682
# 💾 [Baseline] Đã lưu model tại: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/svm.pkl

# %% [markdown]
# ## Naive Bayes

# %%
print(f"\n{'='*20} NAIVE BAYES {'='*20}")

# 1. Khoi tao va Train
nb_model = BaselineModel(model_type='naive_bayes')
nb_model.train(X_train_stat, y_train_stat)

# 2. Danh gia
print("\nKet qua tren tap Validation (Naive Bayes):")
y_pred_nb = nb_model.predict(X_val_stat)
print(classification_report(y_val_stat, y_pred_nb))

# 3. Ve Confusion Matrix
plot_cm(y_val_stat, y_pred_nb, title="Confusion Matrix - Naive Bayes")

# 4. Luu model
save_path_nb = os.path.join(PROJECT_PATH, 'demo', 'artifacts', 'naive_bayes.pkl')
nb_model.save(save_path_nb)
# Out:
# ==================== NAIVE BAYES ====================
# -> [Baseline] Đang huấn luyện mô hình: naive_bayes...
# -> [Baseline] Huấn luyện hoàn tất.
#
# Ket qua tren tap Validation (Naive Bayes):
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88       534
#            1       1.00      0.01      0.02        82
#            2       0.00      0.00      0.00        66
#
#     accuracy                           0.78       682
#    macro avg       0.59      0.34      0.30       682
# weighted avg       0.73      0.78      0.69       682
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 💾 [Baseline] Đã lưu model tại: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/naive_bayes.pkl

# %% [markdown]
# ## Logicstic Regression

# %%
print(f"\n{'='*20} LOGISTIC REGRESSION {'='*20}")

# 1. Khoi tao va Train
logreg_model = BaselineModel(model_type='logreg')
logreg_model.train(X_train_stat, y_train_stat)

# 2. Danh gia
print("\nKet qua tren tap Validation (Logistic Regression):")
y_pred_logreg = logreg_model.predict(X_val_stat)
print(classification_report(y_val_stat, y_pred_logreg))

# 3. Ve Confusion Matrix
plot_cm(y_val_stat, y_pred_logreg, title="Confusion Matrix - Logistic Regression")

# 4. Luu model
save_path_logreg = os.path.join(PROJECT_PATH, 'demo', 'artifacts', 'logreg.pkl')
logreg_model.save(save_path_logreg)
# Out:
# ==================== LOGISTIC REGRESSION ====================
# -> [Baseline] Đang huấn luyện mô hình: logreg...
# -> [Baseline] Huấn luyện hoàn tất.
#
# Ket qua tren tap Validation (Logistic Regression):
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       534
#            1       0.38      0.48      0.42        82
#            2       0.41      0.48      0.44        66
#
#     accuracy                           0.75       682
#    macro avg       0.56      0.60      0.57       682
# weighted avg       0.78      0.75      0.76       682
# 💾 [Baseline] Đã lưu model tại: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/logreg.pkl

# %% [markdown]
# ## PhoBERT

# %%
# 1. Tính Class Weights (Xử lý mất cân bằng)
classes = np.unique(y_train_dl)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_dl)
print(f" Class Weights: {weights}")

# 2. Khởi tạo PhoBERT
phobert_model = PhoBERTClassifier(model_name="vinai/phobert-base")

# 3. Huấn luyện (Train)
print("\n Đang huấn luyện PhoBERT...")
phobert_model.train(
    train_texts=X_train_dl,
    train_labels=y_train_dl,
    val_texts=X_val_dl,
    val_labels=y_val_dl,
    output_dir="./demo/artifacts/phobert_checkpoints", # Lưu checkpoint tạm
    class_weights=weights,
    epochs=10
)
# Out:
#  Class Weights: [0.42562868 2.76936466 3.45494028]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#  Đang huấn luyện PhoBERT...
# [PhoBERT] Bắt đầu huấn luyện trên thiết bị: cuda
#     <div>
#
#       <progress value='1990' max='1990' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1990/1990 17:23, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.051900</td>
#       <td>0.935734</td>
#       <td>0.427941</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.799500</td>
#       <td>0.809588</td>
#       <td>0.502149</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.645700</td>
#       <td>0.765603</td>
#       <td>0.571680</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.548900</td>
#       <td>0.749349</td>
#       <td>0.603395</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.484600</td>
#       <td>0.821558</td>
#       <td>0.605263</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.366100</td>
#       <td>1.033780</td>
#       <td>0.619516</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.247400</td>
#       <td>1.195716</td>
#       <td>0.622873</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.176900</td>
#       <td>1.240857</td>
#       <td>0.639448</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.199500</td>
#       <td>1.366686</td>
#       <td>0.631495</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.245600</td>
#       <td>1.488283</td>
#       <td>0.623106</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# 1. Dự đoán trên tập Val
print("Đang đánh giá PhoBERT trên tập Validation...")
y_pred_phobert = phobert_model.predict(X_val_dl)

# 2. Báo cáo chi tiết (Classification Report)
print("\n--- PhoBERT Classification Report ---")
print(classification_report(y_val_dl, y_pred_phobert))

# 3. Vẽ Confusion Matrix
plot_cm(y_val_dl, y_pred_phobert, title="PhoBERT Confusion Matrix")
# Out:
# Đang đánh giá PhoBERT trên tập Validation...
# --- PhoBERT Classification Report ---
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       534
#            1       0.40      0.46      0.43        82
#            2       0.55      0.55      0.55        66
#
#     accuracy                           0.80       682
#    macro avg       0.62      0.63      0.62       682
# weighted avg       0.81      0.80      0.80       682

# %%
# Tao DataFrame so sanh
df_debug = pd.DataFrame({
    'ID': df_val_dl['id'],
    'Text': df_val_dl['text'],
    'Actual': y_val_dl,
    'Predicted': y_pred_phobert
})

# Loc cac dong du doan sai
wrong_preds = df_debug[df_debug['Actual'] != df_debug['Predicted']]

print(f"Tong so cau sai: {len(wrong_preds)}")

# Cau hinh pandas de hien thi toan bo noi dung va tat ca cac dong
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# 323                                                                                                                                                                                       hình_thể mỏng với số_đo 87 63 98 cm = > số_đo này không hề mỏng nhìn ảnh thì không có được như vậy tôi nghi_ngờ sự chính_xác của số_đo 3 vòng này
# 324                                                                                                                                                                                                                                                                                                                           hoành kim cốt
# 327                                                                                                                                                                                                                                                                                                                      nam vương lè khe ạ
# 334                                                                                                                                                                                                                                                           nếu bỏ son_phấn tôi mới tin grinning face with sweat grinning face with sweat
# 335                                                                                                                                                                                                                                                                                                          trắng không đều vậy em bb trần
# 336                                                                                                                                                                                                                                                                                       chị ơi chị mập lên rồi ạ grinning face with sweat
# 342                                                                                                                                                                                                                                                                          chắc gu thẩm_mỹ của tui lạ tui thấy không đẹp chút nào đứng đơ
# 343                                                                                                                                                                                                                                                                                đề_nghị nam vương dòm thẳng không được ngó ngang ngó dọc
# 346                                                                                                                                                                                                                                                                                           nhìn mặt của ông hùng đứng đơ như cây cơ luôn
# 350                                                                                                                                                                                                       tây mà mấy ai xấu đâu chỉ là họ không biết giữ_gìn bê_tha mới bầy_hầy ra thôi chứ bình_thường thì 10 người hết 7 người là đẹp rồi
# 365                                                                                                                                                                                                                                                            làm gái mà nhan_sắc của thanh tâm chắc tầm 500k 1 lần face with tears of joy
# 371                                                                                                                                                                                                                                                                                                  gương_mặt học_sinh thân_hình phụ_huynh
# 374                                                                                                                                                                                                                                                           myamar nhìn tưởng anh_em thất_lạc của lương bằng quang face with tears of joy
# 376                                                                                                                                                                                                                                                                                người khổng_lồ và chiếc xe tí_hon face with tears of joy
# 379                                                                                                                                                                                                                                                                                                                    vẫn còn nhiều mỡ lắm
# 382                                                                                                                                                                                                                                                                                             cái con lợn này để tao xem 3 năm nữa ra sao
# 383                                                                                                                                                                                                                                          bỏ phấn_son thì cô này bthuong gầy so với tiêu_chuẩn mih thích nhất mái_tóc và thàn_thí cô này
# 384                                                                                                                                                                                                                                                                                                            em xinh như hoa hoa tiến héo
# 388                                                                                                                                                                                                                                                                                                hình_như kích_thước cơ_thể lớn hơn trước
# 399                                                                                                                                                                                                                                                                                                      vậy chứ đẹp_trai là nó khen ngay à
# 402                                                                                                                                                 vấn_đề là cô ấy không hề đẹp như ảnh nếu chưa photoshop chụp cam thường cô ấy như hầu_hết phụ_nữ 40 khác ngoài 40 thì khoẻ cân_đối đủ dinh_dưỡng quan_trọng hơn là hà_khắc với bản_thân
# 404                                                                                                                                                                                                                                                                                                     xem xong là núi lắm rừng clown face
# 407                                                                                                                                                                                                                                                                                               xem nảy giờ mà không biết đang nấu món gì
# 411                                                                                                                                                                                                                                                                                                                      sít rịt lè khe kìa
# 412                                                                                                                                                                                                                                                                                tẩy_trang là biết liền mà smiling face with smiling eyes
# 415                                                                                                                                                                                                                                                      đẹp rồi đẹp như thị nở rolling on the floor laughing rolling on the floor laughing
# 422                                                                                                                                                                                                                                                                                                     nhân_vật này thà làm quả lọ cho mát
# 428                                                                                                                                                                                                                                                                                                                dẹo xương_sống không chị
# 436                                                                                                                                                                                                                                                                      đây là lý_do tại_sao người_ngoài hành_tinh không ghé thăm trái_đất
# 602                                                                                                                                                                                                                                                                      gái già free mà face with tears of joy sao húp của ngta 3k lun_vậy
# 614                                                                                                                                                                                                                                                                                                                      ung_thư mà mập_thể
# 626                                                                                                                                                                                                    muốn được 3 vòng tiêu_chuẩn đòi_hỏi người phụ_nữ kiêng ăn và tập_luyện cánh đàn_ông cũng vậy 6 mũi rất khó còn một múi thì đầy đường
# 627                                                                                                                                                                                                                                                                                  mình không thấy cô này xinh mặt rất cứng không cảm_xúc
# 628                                                                                                                                                                                                     đây cũng là 1trong nhiều con nổ lại còn lanh_chanh phét_lác . . chỉ mong nó đừng lôi thằng nhật khù_khờ chung thuyền với nó là được
# 632                                                                                                                                                                                                                                                        nam_chính này kén ăn hỉ ? toàn da bọc_xương ? grinning face with sweat thumbs up
# 640                                                                                                                    em mai phương thúy 1m8 đã thấy cao lắm rồi bé này tận 1m86 nhìn ảnh thế thôi chứ ngoài đời nhìn như cây sào thực_sự cá_nhân mình thấy cao quá không thấy đẹp tỷ_lệ phom người phụ_nữ cân_đối tầm 1m7 1m75 là đẹp rồi
# 650                                                                                                                                                                                                                                                        hên là mình là người Việt_Nam_á chứ chung nước với ông này chắc mắc_cỡ chết luôn
# 656                                                                                                                                                                                                                                                                                                                  cái miệng tới mang_tai
# 658                                                                                                                                                                                                                                                                                                  tập được 2 ngày thấy đăng hốc nhìu hơn
# 670                                                                                                                                                                                                                                                                          đây chính là ma_nhân bư bảy viện ngọc rồng đời thực sao kakaka
# 675                                                                                                                                                                                                                                                   duyên với xinh vậy_mà vẫn chưa có bồ thì chắc là hơi nặng thật face with tears of joy
# 676                                                                                                                                                                                                                                                                                                              địt con_mẹ xấu vãi cả lồin
# 680                                                                                                                                                                                                                                                                                     quỳ xuống sợ ra sí rịt là ớt_hiểm khế tàu chuối cao
# 681                                                                                                                                                                                                                                                                                      bầu bì không được đùa_giỡn smiling face with horns
#
#      Actual  Predicted
# 3         0          1
# 14        0          2
# 44        0          1
# 46        0          1
# 53        1          0
# 54        0          1
# 58        2          1
# 63        0          1
# 73        1          0
# 75        2          0
# 80        0          1
# 86        0          2
# 88        2          0
# 103       0          2
# 111       0          1
# 115       2          0
# 126       0          1
# 138       0          1
# 146       0          1
# 147       0          1
# 155       0          2
# 162       2          0
# 163       0          2
# 171       0          2
# 181       1          2
# 185       0          2
# 189       2          0
# 201       0          1
# 202       0          1
# 204       2          1
# 205       0          1
# 207       2          1
# 213       1          0
# 217       1          0
# 221       2          1
# 222       1          2
# 223       1          0
# 224       1          0
# 227       0          1
# 231       1          0
# 232       0          1
# 234       1          0
# 241       2          1
# 245       0          2
# 246       2          0
# 256       1          0
# 264       1          0
# 265       0          2
# 268       1          0
# 269       0          1
# 281       2          0
# 283       1          0
# 285       0          1
# 286       0          2
# 289       0          2
# 294       0          2
# 300       0          2
# 302       0          1
# 309       2          0
# 313       1          0
# 318       1          2
# 319       0          1
# 320       2          1
# 323       1          0
# 324       0          1
# 327       1          0
# 334       1          0
# 335       1          0
# 336       1          0
# 342       2          0
# 343       1          0
# 346       0          2
# 350       0          2
# 365       1          0
# 371       1          0
# 374       0          1
# 376       2          1
# 379       1          2
# 382       2          1
# 383       2          0
# 384       1          0
# 388       0          1
# 399       1          0
# 402       1          0
# 404       0          1
# 407       0          1
# 411       0          1
# 412       1          0
# 415       1          0
# 422       0          1
# 428       0          2
# 436       0          1
# 448       0          1
# 457       2          1
# 458       1          0
# 461       1          0
# 465       2          1
# 475       1          0
# 481       0          2
# 490       2          1
# 493       2          0
# 494       0          1
# 495       0          2
# 498       1          0
# 499       2          1
# 516       0          1
# 527       2          1
# 530       0          1
# 533       2          1
# 541       0          1
# 543       1          0
# 545       0          1
# 553       0          2
# 556       0          1
# 562       1          0
# 563       0          1
# 566       0          2
# 573       0          2
# 576       0          2
# 585       0          1
# 592       0          1
# 600       1          0
# 602       2          0
# 614       2          1
# 626       0          1
# 627       2          0
# 628       0          2
# 632       1          2
# 640       2          0
# 650       1          0
# 656       2          1
# 658       1          0
# 670       1          0
# 675       1          0
# 676       1          2
# 680       1          2
# 681       0          1
# Da luu file tai: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/wrong_predictions.csv

# %%
# Lưu Model tốt nhất
SAVE_PATH = os.path.join(PROJECT_PATH, 'demo', 'artifacts', 'phobert_final')

print(f"Đang lưu model vào: {SAVE_PATH}")
phobert_model.save(SAVE_PATH) # Lệnh này sẽ lưu config.json, model.safetensors, v.v.
print("Đã lưu xong!")
# Out:
# Đang lưu model vào: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/phobert_final
# [PhoBERT] Đã lưu model tại: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/phobert_final
# Đã lưu xong!

# %%
import pandas as pd
import os

print(f"{'='*20} FINAL TEST EVALUATION {'='*20}")

# 1. Du doan tren tap Test
# X_test_dl va y_test_dl da duoc load tu Cell Data
print("Dang du doan tren tap Test...")
y_pred_test = phobert_model.predict(X_test_dl)

# 2. In Bao cao ket qua (Classification Report)
print("\n--- Classification Report (Test Set) ---")
print(classification_report(y_test_dl, y_pred_test))

# 3. Ve Confusion Matrix
plot_cm(y_test_dl, y_pred_test, title="PhoBERT Final Result - Test Set")

# 4. Luu ket qua chi tiet ra file CSV
# Tao DataFrame ket qua
df_final_result = df_test_dl.copy()
df_final_result['actual_label'] = y_test_dl
df_final_result['predicted_label'] = y_pred_test

# Map nhan sang chu cho de doc (Optional)
label_map = {0: 'Binh thuong', 1: 'Mia mai', 2: 'Xuc pham'}
df_final_result['predicted_text'] = df_final_result['predicted_label'].map(label_map)

# Luu file
save_path = os.path.join(PROJECT_PATH, 'demo', 'artifacts', 'final_test_prediction.csv')
df_final_result.to_csv(save_path, index=False)

print(f"\nDa luu file ket qua cuoi cung tai: {save_path}")
# Out:
# ==================== FINAL TEST EVALUATION ====================
# Dang du doan tren tap Test...
# --- Classification Report (Test Set) ---
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       534
#            1       0.42      0.46      0.44        82
#            2       0.53      0.61      0.56        66
#
#     accuracy                           0.79       682
#    macro avg       0.61      0.64      0.63       682
# weighted avg       0.80      0.79      0.80       682
# Da luu file ket qua cuoi cung tai: /content/drive/My Drive/DS102_BodyShaming_Classification/demo/artifacts/final_test_prediction.csv
